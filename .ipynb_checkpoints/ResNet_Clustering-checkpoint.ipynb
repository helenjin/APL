# %%
import pandas as pd
import numpy as np

# %matplotlib inline
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

from datetime import datetime

import cv2
from itertools import product
import random

# %% [markdown]
# First, load the features.

# %%
time_start = datetime.now()

resnet_model_avg_pool_features = pd.read_csv('resnet_model_avg_pool_features.csv', sep=',', header=None)

print('This step took time:', datetime.now() - time_start)
# Out:
# This step took time: 0:00:24.273694

# %%
resnet_model_avg_pool_features.head()
# Out:
#        0         1         2         3         4         5        6     \
# 0  0.044459  0.015192  0.123056  0.022544  0.014685  0.000000  0.05411
# 1  0.293910  0.038120  0.647624  0.000000  0.015009  0.000000  0.00000
# 2  0.517993  0.176398  0.394562  0.059750  0.099761  0.000000  0.00000
# 3  0.042720  0.012544  0.126772  0.000000  0.000000  0.000000  0.00000
# 4  0.184237  0.083868  0.667117  0.013950  0.230940  0.029605  0.00000
#
#        7        8         9       ...         2038  2039     2040      2041  \
# 0  0.000000  0.00000  0.000000    ...     0.000000   0.0  0.00000  0.000000
# 1  0.000000  0.00000  0.000000    ...     0.000000   0.0  0.00000  0.000000
# 2  0.000000  0.00000  0.000000    ...     0.000000   0.0  0.00000  0.000000
# 3  0.000000  0.00000  0.000000    ...     0.002528   0.0  0.07413  0.000000
# 4  0.035334  0.00085  0.038493    ...     0.055583   0.0  0.00000  0.148272
#
#    2042      2043      2044      2045      2046      2047
# 0   0.0  0.000000  0.000000  0.033316  0.000000  0.000000
# 1   0.0  0.000000  0.000000  0.053812  0.000000  0.000000
# 2   0.0  0.000000  0.000000  0.000000  0.000000  0.000000
# 3   0.0  0.000000  0.011844  0.000000  0.090980  0.000000
# 4   0.0  0.032973  0.031295  0.000000  0.078041  0.012546
#
# [5 rows x 2048 columns]

# %%
resnet_model_avg_pool_features.shape
# Out:
# (40000, 2048)

# %% [markdown]
# Then, we will standardize the features and perform clustering.

# %%
time_start = datetime.now()

kmeans = KMeans(n_clusters=20, max_iter=30, random_state=2019)

print('This step took time:', datetime.now() - time_start)
# Out:
# This step took time: 0:00:00

# %%
time_start = datetime.now()

kmeans.fit(resnet_model_avg_pool_features.values)

print('This step took time:', datetime.now() - time_start)
# Out:
# This step took time: 0:04:08.559514

# %%
time_start = datetime.now()

output = kmeans.predict(resnet_model_avg_pool_features.values)

print('This step took time:', datetime.now() - time_start)
# Out:
# This step took time: 0:00:03.266653

# %% [markdown]
# ## Identifying Palm Clusters
# In this csv file, each row represents a ground observation. And the feature “pix_1” corresponds the column in the image, and “pix_2” corresponds to the row in the image. For example, the first data point has value pix_1 = 8132, pix_2 = 16017, which means its location is 16017th row, and 8132nd column in the image.

# %%
lfdp_ground_labels = pd.read_csv("LFDP_ground_labels.csv")
lfdp_ground_labels = lfdp_ground_labels.drop('Unnamed: 0', axis=1)

lfdp_palm = lfdp_ground_labels.loc[(lfdp_ground_labels['SPECIES'] == 'PREMON') & (lfdp_ground_labels['ALIVE'] == 'A')]
lfdp_palm = lfdp_palm[lfdp_palm['DIAM'] >= 20]
lfdp_palm.head()
# Out:
#       Unnamed: 0.1  STEM.TAG  QUAD  SUBQUAD      X       Y SPECIES  CENSUS  \
# 765         484772    6518.0   108       32  11.52  145.91  PREMON       6
# 2314        486384   17926.0   123       33  14.08  452.41  PREMON       6
# 3909        488055  171526.0   214       42  35.19  269.20  PREMON       6
# 4259        488423   14337.0   217       31  30.54  321.37  PREMON       6
# 4989        489173   17942.0   223       23  26.53  450.48  PREMON       6
#
#       DIAM ALIVE      coords.x1      coords.x2  pix_1  pix_2
# 765   20.0     A  265155.806401  254323.465978   8489  11719
# 2314  20.7     A  265159.451067  254629.114280   8629   2547
# 3909  20.2     A  265179.882966  254446.367808   9224   8033
# 4259  20.0     A  265175.424270  254498.403076   9095   6471
# 4989  20.8     A  265171.877860  254627.164549   9002   2606

# %%
palm_num = np.zeros(20)
for index, entry in lfdp_palm.iterrows():
    patch_col = entry['pix_1'] // 100
    patch_row = entry['pix_2'] // 100 

    patches_i = patch_row*200 + patch_col
    palm_num[output[patches_i]] += 1
    
    
cluster_size = np.zeros(20)
min_patch_row = min(lfdp_ground_labels['pix_2']) // 100
max_patch_row = max(lfdp_ground_labels['pix_2']) // 100

min_patch_col = min(lfdp_ground_labels['pix_1']) // 100
max_patch_col = max(lfdp_ground_labels['pix_1']) // 100

for patch_row in range(min_patch_row, max_patch_row):
    for patch_col in range(min_patch_col, max_patch_col):
        patches_i = patch_row * 200 + patch_col
        cluster_size[output[patches_i]] += 1
    
palm_relevance = palm_num / (cluster_size + 1)
palm_relevance
# Out:
# array([0.02580645, 0.00232829, 0.0052687 , 0.00218341, 0.0075358 ,
#        0.00943396, 0.00838323, 0.00261438, 0.00377358, 0.00305111,
#        0.007034  , 0.00131406, 0.00151976, 0.004158  , 0.        ,
#        0.        , 0.00618557, 0.        , 0.02101576, 0.00205761])

# %%
sorted_cluster = np.array(sorted(range(len(palm_relevance)), key=lambda k: palm_relevance[k]), dtype=str)
sorted_palm_relevance = np.sort(palm_relevance)

plt.figure(figsize=(6, 3))
plt.bar(sorted_cluster, sorted_palm_relevance)
plt.title('Palm Relevance of Each Cluster')
plt.xlabel('Cluster ID', fontsize=12)
plt.ylabel('Relevance with Palm Labels', fontsize=12)
plt.show()

plt.figure(figsize=(6, 3))
plt.bar(sorted_cluster, cluster_size[sorted_cluster.astype(int)], color='green')
plt.title('Size of Each Cluster')
plt.xlabel('Cluster ID', fontsize=12)
plt.ylabel('Number of Patches', fontsize=12)
plt.show()

print('In total, PREMON density is', palm_num.sum()/cluster_size.sum())
# Out:
# In total, PREMON density is 0.005085910652920962

# %% [markdown]
# ### Patches in Palm Cluster(s) Visualization
# we will visualize top 3 for now

# %%
# need to actually get the patches again, so that we can pick the correct patches and stitch them up to create our visualization
img = cv2.imread("shadow_remove.jpg")
patches = [img[i*100:(i+1)*100,j*100:(j+1)*100] for i, j in product(range(int(img.shape[0]/100)), range(int(img.shape[1]/100)))]
patches = np.asarray(patches)

# %%
fig = plt.figure(figsize=(12,12)) 

subplot_i = 1
for cluster in sorted_cluster.astype(int)[-3:]:
    # we will view a random 25 patches for each cluster
    indices = [i for i, x in enumerate(output) if x == cluster]
    indices_pos = random.sample(range(len(indices)), 25) # positions of selected elements in indices

    new_img = np.zeros(shape=(500, 500, 3), dtype=int)
    for i in range(5):
        for j in range(5):
            patch_id = i*5 + j # basically acts like a variable that goes from 0 to 24 consecutively
            new_img[i*100:(i+1)*100, j*100:(j+1)*100] = patches[indices[indices_pos[patch_id]],:,:,:]
    
    # let's save the image in the cluster_images folder
    cv2.imwrite('cluster_images/resnet_model_avg_pool_palm_cluster' + str(cluster) + '.jpg', new_img)
    
    fig.add_subplot(1,3,subplot_i), plt.imshow(new_img), plt.title('Cluster ' + str(cluster))
    subplot_i+=1

plt.show()

# %% [markdown]
# ## Identifying Cecropia Clusters

# %%
# lfdp_ground_labels = pd.read_csv("LFDP_ground_labels.csv")
# lfdp_ground_labels = lfdp_ground_labels.drop('Unnamed: 0', axis=1)

# don't need to do the above if you already identified Palm Clusters in the previous step

lfdp_cecropia = lfdp_ground_labels.loc[(lfdp_ground_labels['SPECIES'] == 'CECSCH') & (lfdp_ground_labels['ALIVE'] == 'A')]
lfdp_cecropia = lfdp_cecropia[lfdp_cecropia['DIAM'] >= 20]
lfdp_cecropia.head()
# Out:
#      Unnamed: 0.1  STEM.TAG  QUAD  SUBQUAD      X       Y SPECIES  CENSUS  \
# 258        484243     807.0   103       11   4.24   43.12  CECSCH       6
# 629        484628   29158.0   106       44  17.12  118.78  CECSCH       6
# 851        484870   48491.0   109       31  10.64  160.46  CECSCH       6
# 992        485014  134310.0   110       41  19.70  181.65  CECSCH       6
# 993        485015  134312.0   110       41  17.51  182.22  CECSCH       6
#
#      DIAM ALIVE      coords.x1      coords.x2  pix_1  pix_2
# 258  22.4     A  265148.171075  254220.974535   8249  14794
# 629  27.9     A  265161.302736  254296.399638   8651  12532
# 851  24.8     A  265154.979207  254337.977563   8465  11283
# 992  27.0     A  265164.102526  254359.090799   8741  10650
# 993  29.3     A  265161.917427  254359.663633   8676  10633

# %%
cecropia_num = np.zeros(20)
for index, entry in lfdp_cecropia.iterrows():
    patch_col = entry['pix_1'] // 100
    patch_row = entry['pix_2'] // 100 

    patches_i = patch_row*200 + patch_col
    cecropia_num[output[patches_i]] += 1
    
    
# cluster_size = np.zeros(20)
# min_patch_row = min(lfdp_ground_labels['pix_2']) // 100
# max_patch_row = max(lfdp_ground_labels['pix_2']) // 100

# min_patch_col = min(lfdp_ground_labels['pix_1']) // 100
# max_patch_col = max(lfdp_ground_labels['pix_1']) // 100

# for patch_row in range(min_patch_row, max_patch_row):
#     for patch_col in range(min_patch_col, max_patch_col):
#         patches_i = patch_row * 200 + patch_col
#         cluster_size[output[patches_i]] += 1

# don't need to do the above if you already identified Palm Clusters in the previous step
    
cecropia_relevance = cecropia_num / (cluster_size + 1)
cecropia_relevance
# Out:
# array([0.04516129, 0.03317811, 0.02212856, 0.00655022, 0.02486812,
#        0.10188679, 0.04191617, 0.0379085 , 0.02264151, 0.05263158,
#        0.03868699, 0.01576873, 0.02279635, 0.04261954, 0.02592593,
#        0.03589744, 0.03505155, 0.04072398, 0.01401051, 0.01440329])

# %%
sorted_cluster = np.array(sorted(range(len(cecropia_relevance)), key=lambda k: cecropia_relevance[k]), dtype=str)
sorted_cecropia_relevance = np.sort(cecropia_relevance)

plt.figure(figsize=(6, 3))
plt.bar(sorted_cluster, sorted_cecropia_relevance)
plt.title('Cecropia Relevance of Each Cluster')
plt.xlabel('Cluster ID', fontsize=12)
plt.ylabel('Relevance with Cecropia Labels', fontsize=12)
plt.show()

plt.figure(figsize=(6, 3))
plt.bar(sorted_cluster, cluster_size[sorted_cluster.astype(int)], color='green')
plt.title('Size of Each Cluster')
plt.xlabel('Cluster ID', fontsize=12)
plt.ylabel('Number of Patches', fontsize=12)
plt.show()

print('In total, CECSCH density is', cecropia_num.sum()/cluster_size.sum())
# Out:
# In total, CECSCH density is 0.033539518900343644

# %% [markdown]
# ### Patches in Cecropia Cluster(s) Visualization
# we will visualize top 3 for now

# %%
# # need to actually get the patches again, so that we can pick the correct patches and stitch them up to create our visualization
# img = cv2.imread("shadow_remove.jpg")
# patches = [img[i*100:(i+1)*100,j*100:(j+1)*100] for i, j in product(range(int(img.shape[0]/100)), range(int(img.shape[1]/100)))]
# patches = np.asarray(patches)

# don't need to do this if you already identified Palm Clusters in the previous step

# %%
fig = plt.figure(figsize=(12,12)) 

subplot_i = 1
for cluster in sorted_cluster.astype(int)[-3:]:
    # we will view a random 25 patches for each cluster
    indices = [i for i, x in enumerate(output) if x == cluster]
    indices_pos = random.sample(range(len(indices)), 25) # positions of selected elements in indices

    new_img = np.zeros(shape=(500, 500, 3), dtype=int)
    for i in range(5):
        for j in range(5):
            patch_id = i*5 + j # basically acts like a variable that goes from 0 to 24 consecutively
            new_img[i*100:(i+1)*100, j*100:(j+1)*100] = patches[indices[indices_pos[patch_id]],:,:,:]
    
    # let's save the image in the cluster_images folder
    cv2.imwrite('cluster_images/resnet_model_avg_pool_cecropia_cluster' + str(cluster) + '.jpg', new_img)
    
    fig.add_subplot(1,3,subplot_i), plt.imshow(new_img), plt.title('Cluster ' + str(cluster))
    subplot_i+=1

plt.show()
